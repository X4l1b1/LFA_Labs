# %% [markdown]
# # C-mean Clustering
# Fuzzy c-Means Clustering} (FMC) is a clustering method which, unlike Hard k-Means Clustering, allows a data sample to more or less belong to one or more clusters. In this notebook, we will try to develop a semi-supervised C-mean Clustering.

# %% [markdown]
# ## Loading the packages

# %%
import numpy as np
import matplotlib.pyplot as plt

import random
import operator
import math
colors = ['b', 'orange', 'g', 'r', 'c', 'm', 'y', 'k', 'Brown', 'ForestGreen']

PATH_TO_DATASET = '' # Not Given Yet 

# %matplotlib inline

# %% [markdown]
# ## The dataset
# The following script allows you to create a 2D dataset by using the mouse. The fift first click adds points belonging to class A (blue), the 5th following click adds points belonging to class B (red) and the next click add unclassified points. You can create as many points as you desire. The final dataset will contain hence three values per point: x coordinate (-1 ≤ x ≤ 1), y coordinate (-1 ≤ y ≤ 1) and the class ∈ {0,1,2} where 0 represent unclassified points.

# %%
# %matplotlib notebook

fig = plt.figure(figsize=(6,6))
plt.title("Input Dataset")
plt.xlim((-1.2,1.2))
plt.ylim((-1.2,1.2))

dataset = []

i = 0
def onclick(event):
    global dataset
    global i
    cx = event.xdata
    cy = event.ydata
    classe = 1 if(i<10) else 2 if(i<20) else 0
    i=i+1
    dataset.append((cx, cy, classe))

    plt.scatter(cx, cy, c=['k', 'b', 'r'][classe], s=100, lw=0)
    plt.grid(True)

cid = fig.canvas.mpl_connect('button_press_event', onclick)
# Out:
# <div id='a4fa22e8-60b9-4f38-9cf3-9beadc046b56'></div>

# %%
import numpy as np

def random_positive_semidefinite_matrix(d):
    Q = np.random.randn(d, d)
    eigvals = np.random.rand(d)
    return Q.T @ np.diag(eigvals) @ Q
    
    while True:
        A = np.random.rand(d, d)
        A += A.T
        if np.all(np.linalg.eigvals(A) > 0):
            return A

def make_spiral_clusters(c, cluster_size, n_noise, d=2):
    angle = np.linspace(0, 2*np.pi, c, endpoint=False)
    radius = np.linspace(10, 30, c)
    vx = np.cos(angle)*radius
    vy = np.sin(angle)*radius
    v = np.stack([vx, vy], axis=1)

    covariances = np.array([random_positive_semidefinite_matrix(d) for _ in range(c)])

    x = np.concatenate([np.random.multivariate_normal(v[i], covariances[i], cluster_size)
        for i in range(c)], axis=0)

    u = np.random.rand(n_noise, d)
    noise = np.min(x, axis=0)*u + (1 - u)*np.max(x, axis=0)

    x = np.concatenate([x, noise], axis=0)

    return x, v


dataset, true_centers = make_spiral_clusters(5, 50, 0)

labels = [1]*int(len(dataset)/5) + [2]*int(len(dataset)/5) + [1]*int(len(dataset)/5) + [2]*int(len(dataset)/5)+ [1]*int(len(dataset)/5)
for i in range(150):
    labels[np.random.randint(len(labels))] = 0

fig2 = plt.figure(figsize=(6,6))
plt.title("Output Dataset")

plt.scatter(dataset[:,0], dataset[:,1], c=[(['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w'])[int(label)] for label in labels])
plt.grid()
plt.show()
print(dataset)

# %%
dataset = np.array(dataset)
labels = np.expand_dims(labels, axis=1)
dataset = np.append(dataset, labels, axis=1)
fig2 = plt.figure(figsize=(6,6))
plt.title("Output Dataset")

#  [ 1.07945812e+01 -2.69065703e+01  0.00000000e+00]
#  [ 6.90281449e+00 -2.96858628e+01  0.00000000e+00]
#  [ 7.37832949e+00 -3.04857111e+01  0.00000000e+00]
#  [ 8.21330696e+00 -2.94591954e+01  1.00000000e+00]
#  [ 1.05996144e+01 -2.70010694e+01  0.00000000e+00]
#  [ 8.94662719e+00 -2.92973980e+01  0.00000000e+00]
#  [ 7.94346299e+00 -2.99993710e+01  0.00000000e+00]
#  [ 9.30644391e+00 -2.82273258e+01  0.00000000e+00]
#  [ 9.11952928e+00 -2.89798803e+01  0.00000000e+00]
#  [ 8.50155145e+00 -2.98197261e+01  1.00000000e+00]
#  [ 1.07414272e+01 -2.67768798e+01  1.00000000e+00]
#  [ 9.20738235e+00 -2.78627557e+01  0.00000000e+00]
#  [ 9.61582165e+00 -2.81682719e+01  0.00000000e+00]
#  [ 8.43909556e+00 -2.88387067e+01  0.00000000e+00]
#  [ 9.57185709e+00 -2.94439302e+01  0.00000000e+00]]

# %% [markdown]
# ## Membership Matrix
# The Membership matrix lists all the data samples membership grades to a particular cluster. Here we first randomly initialize it.

# %%
def initializeMembershipMatrix(dataset, k):
    membership_mat = list()
    for i in range(len(dataset)):
        random_num_list = [random.random() for i in range(k)]
        summation = sum(random_num_list)
        temp_list = [x/summation for x in random_num_list]
        membership_mat.append(temp_list)
    return membership_mat

# %% [markdown]
# ## Cluster Center
# Here we calculate each cluster center depending on the membership grades.

# %%
def calculateClusterCenter(dataset, membership_mat, k, fuzzy_param):
    cluster_mem_val = list(zip(*membership_mat))
    cluster_centers = list()
    for j in range(k):
        x = cluster_mem_val[j]
        xraised = [e ** fuzzy_param for e in x]
        denominator = sum(xraised)
        temp_num = list()
        for i in range(len(dataset)):
            data_point = dataset[i]
            prod = [xraised[i] * val for val in data_point]
            temp_num.append(prod)
        numerator = map(sum, zip(*temp_num))
        center = [z/denominator for z in numerator]
        cluster_centers.append(center)
    return cluster_centers

# %% [markdown]
# ## Semi-supervised C-Mean

# %%
def evalConvergence(mb, previous_mb, threshold):
    return (np.absolute(np.array(mb) - np.array(previous_mb))).max() < threshold

# %%
def initializeMembershipMatrixSupervised(dataset, k):
    membership_mat_supervised = list()
    for i in range(len(dataset)):
        if (dataset[i][2] == 0):
            random_num_list = [0 for i in range(k)]
        else:
            random_num_list = [1 if((i+1)==dataset[i][2]) else 0 for i in range(k)]
        
        membership_mat_supervised.append(random_num_list)
    return membership_mat_supervised

# %%
def evalAccuracy(dataset, k):
    pass

# %%
def calculateClusterCenterSup(dataset, membership_mat, membership_mat_sup,  k, fuzzy_param):
    cluster_centers = []
    for i in range(k):
        for n in range(len(dataset)):
            denum = abs(membership_mat[n][i] - membership_mat_sup[n][i]) ** fuzzy_param
            num = denum*dataset[n]#dataset[n, :-1] ? 
        cluster_centers.append(num/denum)
    return cluster_centers

# %%
def updateMembershipValueSup(dataset, membership_mat, membership_mat_sup, cluster_centers, fuzzy_param, k):
    def d(n, c):
        return np.linalg.norm(list(map(operator.sub, dataset[n], cluster_centers[c])))** 2
    p = 1/(fuzzy_param- 1)
    
    for i in range(k):
        for n in range(len(dataset)):  
            membership_mat[n][i] = membership_mat_sup[n][i] + (1 - np.sum(membership_mat_sup[n])) * d(n, i) ** p / np.sum([d(n,j) for j in range(k)])
    return membership_mat

# %%
import numpy as np
import scipy.spatial
import copy

def pairwise_squared_distances(A, B):
    return scipy.spatial.distance.cdist(A, B)**2

def calculate_covariances(x, u, v, m):
    c, n = np.array(u).shape
    d = np.array(v).shape[1]
    
    um = np.array(u)**m

    covariances = np.zeros((c, d, d))

    for i in range(c):
        xv = x - v[i]
        uxv = um[i, :, np.newaxis]*xv
        covariances[i] = np.einsum('ni,nj->ij', uxv, xv)/np.sum(um[i])
    
    return covariances

# Partition Coefficient
def pc(x, u, v, m):
    c, n = np.array(u).shape
    return np.square(np.array(u)).sum()/n

# Fuzzy Hyperbolic Volume
def fhv(x, u, v, m):
    covariances = calculate_covariances(x, u, v, m)
    return sum(np.sqrt(np.linalg.det(cov)) for cov in covariances)

# Xie-Beni Index
def xb(x, u, v, m):
    n = np.array(x).shape[0]
    c = np.array(v).shape[0]

    um = np.array(u)**m
    
    d2 = pairwise_squared_distances(x, v)
    v2 = pairwise_squared_distances(v, v)
    
    v2[v2 == 0.0] = np.inf

    return np.sum(um.T*d2)/(n*np.min(v2))

def checkKnownEntriesBetter(dataset, labels, c):
    res = np.zeros((c, 2))
    for cluster in range(c) :
        for i in range(len(dataset)):
            if(dataset[i][-1] != 0 and labels[i] == cluster):
                res[cluster][int(dataset[i][-1] - 1)] += 1
        
   # print("res1", res)
    
    for cluster in range(c):
        c_total = res[cluster][0] + res[cluster][1]
        res[cluster][0] /= c_total
        res[cluster][1] /= c_total

  #  print("res2", res)
    return res
        
    

def checkKnownEntries(x, labels, c):
    
    # 4 columns for each cluster :
    # |# class0 |# class1 | %0 | %1 |
    min_c = min(labels)
    res = [[0 for i in range(4)] for j in range(c)]
    for i in range(len(x)):
        # If the class is known (i.e. not 0)
        if(x[i][-1]!= 0):
            print(str(x[i][-1]))
            res[labels[i] - min_c][int(x[i][-1])-1] = res[labels[i] - min_c][int(x[i][-1])] + 1
            
    for i in range(c):
        if((res[i][0] + res[i][1]) != 0 and (res[i][0] + res[i][1]) != 0):
            res[i][2] = res[i][0] / (res[i][0] + res[i][1])        
            res[i][3] = res[i][1] / (res[i][0] + res[i][1])
        else :
            res[i][2] = 0.5
            res[i][3] = 0.5
    #print(res)
        
    return res

# %%
import numpy as np
from cvi import *

def fcm_get_u(x, v, m):
    distances = pairwise_squared_distances(x, v)
    nonzero_distances = np.fmax(distances, np.finfo(np.float64).eps)
    inv_distances = np.reciprocal(nonzero_distances)**(1/(m - 1))
    return inv_distances.T/np.sum(inv_distances, axis=1)

def fcm(x, c, m=2.0, v=None, max_iter=100, error=0.05):
    if v is None: v = x[np.random.randint(x.shape[0], size=c)]
    u = fcm_get_u(x, v, m)
 #   print('fcm', len(u))

    for iteration in range(max_iter):
        u_old = u
        um = u**m
        v = np.dot(um, x)/np.sum(um, axis=1, keepdims=True)
        u = fcm_get_u(x, v, m)
        if np.linalg.norm(u - u_old) < error: break
    return u, v

# %%
def getClass(dataset, labels, k):
    count_class = np.zeros((k, 2))
    newLabels = copy.copy(labels)
    print('labels', len(labels))
    for i in range(len(dataset)):
        print('dataset', len(dataset))
        print('count_class', len(count_class))
        print('labels', len(labels))
        print(i)
        if(dataset[i][-1] != 0):
            count_class[int(labels[i])][int(dataset[i][-1] - 1)] += 1
    
  #  print(count_class)
    
    for c in range(len(count_class)):     
        if count_class[c][0] < count_class[c][1]:
            cl = 1 
        elif count_class[c][0] > count_class[c][1]:
            cl = 2 
        else :
            cl = 0
            
        for i in range(len(labels)):
            if labels[i] == c:
                newLabels[i] = cl 
            
    return newLabels

def extractCluster(c, dataset, labels):
#    print('Good cluster :', c)
 #   print('dataset', dataset)
    cluster = np.empty((0, len(dataset[0])), float)
    indices = []
    for i in range(len(dataset)):
        if(labels[i] == c):
            cluster = np.vstack((cluster, dataset[i]))
            indices.append(i)
#    print('Cluster', cluster)
    return cluster, indices

# %% [markdown]
# ## Main Execution
# blablabla

# %%
def updateMembershipValue(dataset, membership_mat, cluster_centers, fuzzy_param, k):
    p = float(2/(fuzzy_param-1))
    for i in range(len(dataset)):
        x = dataset[i]
        distances = [np.linalg.norm(list(map(operator.sub, x, cluster_centers[j]))) for j in range(k)]
        for j in range(k):
            den = sum([math.pow(float(distances[j]/distances[c]), p) for c in range(k)])
            membership_mat[i][j] = float(1/den)       
    return membership_mat


def getClusters(dataset, membership_mat):
 #   print("Len  data", len(dataset))

    cluster_labels = list()
#    print((membership_mat))
    for i in range(len(dataset)):
        max_val, idx = max((val, idx) for (idx, val) in enumerate(membership_mat[i]))
        cluster_labels.append(idx)
    return cluster_labels


def fuzzyCMeansClustering(dataset, k = 2, threshold = 0.1, fuzzy_param = 2.00, maxSteps = 100000):
    # Membership Matrix
    membership_mat = initializeMembershipMatrix(dataset, k)
    previous_mb = None
    steps = 0
    
    while previous_mb is None or not evalConvergence(membership_mat, previous_mb, threshold) or steps >= maxSteps:
        cluster_centers = calculateClusterCenter(dataset[:,:-1], membership_mat, k, fuzzy_param)
        membership_mat = updateMembershipValue(dataset[:,:-1], membership_mat, cluster_centers, fuzzy_param, k)
        cluster_labels = getClusters(dataset[:,:-1], membership_mat)
        previous_mb = membership_mat
        steps += 1
    return cluster_labels, cluster_centers, membership_mat

def clusterize(dataset):
    result_labels = np.zeros((len(dataset), len(dataset[0]) + 1), float)
    res_labels = np.zeros((len(dataset), 1), int)

#    result_mb     = [[]]
    result_centers   = []
    temp_data     = copy.copy(dataset)
    found_clusters = 0
    result_index = 0
    c = 2
    done = False
    while(not done and c < math.sqrt(len(dataset))): 
        #labels, centers, mb = fuzzyCMeansClustering(temp_data, k = c)
        mb, centers = fcm(temp_data[:,:-1], c)
        mb_t = mb.T
   #     print('mb', mb)
        labels = getClusters(temp_data[:,:-1], mb_t)
        # First, check supervised values
        # TOFIX : Bordel with cluster indexes, won't work.
        sup_verif = checkKnownEntriesBetter(temp_data, labels, c)
     #   print("verif: ", sup_verif)
        cluster_ok = []
        for i in range(c):
            if(sup_verif[i][0] < 0.1 or sup_verif[i][0] > 0.90):
                cluster_ok.append(i)
  #      print('cluster ok ', cluster_ok)
  #      print('len cluster_ok', len(cluster_ok))
  #      print(sup_verif)
  #      print("Len remaining data", len(temp_data))

        if(len(cluster_ok) == 0):
            # If no cluster is good enough (with known values) restart with more clusters
            c =c + 1
        
        else:
            # Check our values aren't just luckily in same clusters using unsup CVI
            fhv_s = fhv(x = temp_data[:,:-1], v = centers, u = mb, m =2)
            pc_s  = pc(temp_data[:,:-1], mb, centers, 2)
            xb_s  = xb(x = temp_data[:,:-1], u = mb, v = centers, m = 2)
            print('fhvs_', fhv_s)
            print('pc_s', pc_s)
            print('xb_s', xb_s)
            # If clustering is very good, stop
            if(pc_s > 0.85 and xb_s < 0.15 and fhv_s < 20):#fhv_s > 0.1 or 
                for i in range(len(temp_data)):
                        result_labels[result_index] = np.append(temp_data[i], labels[i] + 20)
                        res_labels[result_index]    = int(labels[i] + found_clusters)
                        result_index += 1
                for i in range(len(centers)):
                        result_centers += [centers[i]]
                done = 1
                break
            else:
                for c in cluster_ok :
                    cluster, indices = extractCluster(c, temp_data, labels)
             #       print(len(result_labels))
            #        print(len(cluster))
                    for i in range(len(cluster)):
                        result_labels[result_index] = np.append(cluster[i], found_clusters)
                        res_labels[result_index]    = int(found_clusters)
                        result_index += 1
           #         print('indices', indices)
         #          result_mb.append([])
          #          for i in indices:
          #              result_mb[found_clusters].append([mb_t[i]])
                    result_centers += [centers[int(c)]]
                 #   result_labels = np.append(result_labels[found_clusters], cluster)
                 #   result_labels = np.reshape(result_labels[found_clusters],(len(result_labels)/3, 3))
                    temp_data = np.delete(temp_data, indices, 0)
            #        print('result',result_labels)
                    found_clusters += 1
            c = c - len(cluster_ok) + 2
            if (c < 2):
                c = 2
            continue
    result_centers = np.array(result_centers)
    return res_labels, result_centers

labels, centers = clusterize(dataset)
print('centers', centers)

labels = getClass(dataset, labels, len(centers))
#labels, centers, mb = fuzzyCMeansClustering(dataset, k=2)

#mb, centers = fcm(dataset[:,:-1], 4)
#print(len(mb))
#print(len(mb[0]))

#labels = getClusters(dataset[:,:-1], mb.T )
#print(len(labels))
#print(len(dataset))
#print(mb)

#centers = np.array(centers)
# Visualize the test data

fig2 = plt.figure(figsize=(6,6))
plt.title("Output Dataset")
plt.scatter(dataset[:,0], dataset[:,1], c=[(['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w'])[int(label)] for label in labels])
plt.scatter(centers[:,0], centers[:,1], c='y')
plt.grid()
plt.show()
# Out:
# fhvs_ 89.75199770337139
# pc_s 0.7802649969686407
# xb_s 0.07619494380880529
# fhvs_ 78.49535259028879
# pc_s 0.8465259002918921
# xb_s 0.07629925919908598
# fhvs_ 15.816149874725962
# pc_s 0.8728854398332799
# xb_s 0.06693878718557085
# centers [[-19.34899195 -10.84815052]
#  [  8.91942383 -27.8092672 ]
#  [  8.91898994 -26.63609599]
#  [  7.6932022    6.29522203]
#  [-15.41750631  11.67301461]]
# labels 250
# dataset 250
# count_class 5
# labels 250
# 0
# dataset 250
# count_class 5
# labels 250
# 1
# dataset 250
# count_class 5
# labels 250
# 2
# dataset 250
# count_class 5
# labels 250
# 3
# dataset 250
# count_class 5
# labels 250
# 4
# dataset 250
# count_class 5
# labels 250
# 5
# dataset 250
# count_class 5
# labels 250
# 6
# dataset 250
# count_class 5
# labels 250
# 7
# dataset 250
# count_class 5
# labels 250
# 8
# dataset 250
# count_class 5
# labels 250
# 9
# dataset 250
# count_class 5
# labels 250
# 10
# dataset 250
# count_class 5
# labels 250
# 11
# dataset 250
# count_class 5
# labels 250
# 12
# dataset 250
# count_class 5
# labels 250
# 13
# dataset 250
# count_class 5
# labels 250
# 14
# dataset 250
# count_class 5
# labels 250
# 15
# dataset 250
# count_class 5
# labels 250
# 16
# dataset 250
# count_class 5
# labels 250
# 17
# dataset 250
# count_class 5
# labels 250
# 18
# dataset 250
# count_class 5
# labels 250
# 19
# dataset 250
# count_class 5
# labels 250
# 20
# dataset 250
# count_class 5
# labels 250
# 21
# dataset 250
# count_class 5
# labels 250
# 22
# dataset 250
# count_class 5
# labels 250
# 23
# dataset 250
# count_class 5
# labels 250
# 24
# dataset 250
# count_class 5
# labels 250
# 25
# dataset 250
# count_class 5
# labels 250
# 26
# dataset 250
# count_class 5
# labels 250
# 27
# dataset 250
# count_class 5
# labels 250
# 28
# dataset 250
# count_class 5
# labels 250
# 29
# dataset 250
# count_class 5
# labels 250
# 30
# dataset 250
# count_class 5
# labels 250
# 31
# dataset 250
# count_class 5
# labels 250
# 32
# dataset 250
# count_class 5
# labels 250
# 33
# dataset 250
# count_class 5
# labels 250
# 34
# dataset 250
# count_class 5
# labels 250
# 35
# dataset 250
# count_class 5
# labels 250
# 36
# dataset 250
# count_class 5
# labels 250
# 37
# dataset 250
# count_class 5
# labels 250
# 38
# dataset 250
# count_class 5
# labels 250
# 39
# dataset 250
# count_class 5
# labels 250
# 40
# dataset 250
# count_class 5
# labels 250
# 41
# dataset 250
# count_class 5
# labels 250
# 42
# dataset 250
# count_class 5
# labels 250
# 43
# dataset 250
# count_class 5
# labels 250
# 44
# dataset 250
# count_class 5
# labels 250
# 45
# dataset 250
# count_class 5
# labels 250
# 46
# dataset 250
# count_class 5
# labels 250
# 47
# dataset 250
# count_class 5
# labels 250
# 48
# dataset 250
# count_class 5
# labels 250
# 49
# dataset 250
# count_class 5
# labels 250
# 50
# dataset 250
# count_class 5
# labels 250
# 51
# dataset 250
# count_class 5
# labels 250
# 52
# dataset 250
# count_class 5
# labels 250
# 53
# dataset 250
# count_class 5
# labels 250
# 54
# dataset 250
# count_class 5
# labels 250
# 55
# dataset 250
# count_class 5
# labels 250
# 56
# dataset 250
# count_class 5
# labels 250
# 57
# dataset 250
# count_class 5
# labels 250
# 58
# dataset 250
# count_class 5
# labels 250
# 59
# dataset 250
# count_class 5
# labels 250
# 60
# dataset 250
# count_class 5
# labels 250
# 61
# dataset 250
# count_class 5
# labels 250
# 62
# dataset 250
# count_class 5
# labels 250
# 63
# dataset 250
# count_class 5
# labels 250
# 64
# dataset 250
# count_class 5
# labels 250
# 65
# dataset 250
# count_class 5
# labels 250
# 66
# dataset 250
# count_class 5
# labels 250
# 67
# dataset 250
# count_class 5
# labels 250
# 68
# dataset 250
# count_class 5
# labels 250
# 69
# dataset 250
# count_class 5
# labels 250
# 70
# dataset 250
# count_class 5
# labels 250
# 71
# dataset 250
# count_class 5
# labels 250
# 72
# dataset 250
# count_class 5
# labels 250
# 73
# dataset 250
# count_class 5
# labels 250
# 74
# dataset 250
# count_class 5
# labels 250
# 75
# dataset 250
# count_class 5
# labels 250
# 76
# dataset 250
# count_class 5
# labels 250
# 77
# dataset 250
# count_class 5
# labels 250
# 78
# dataset 250
# count_class 5
# labels 250
# 79
# dataset 250
# count_class 5
# labels 250
# 80
# dataset 250
# count_class 5
# labels 250
# 81
# dataset 250
# count_class 5
# labels 250
# 82
# dataset 250
# count_class 5
# labels 250
# 83
# dataset 250
# count_class 5
# labels 250
# 84
# dataset 250
# count_class 5
# labels 250
# 85
# dataset 250
# count_class 5
# labels 250
# 86
# dataset 250
# count_class 5
# labels 250
# 87
# dataset 250
# count_class 5
# labels 250
# 88
# dataset 250
# count_class 5
# labels 250
# 89
# dataset 250
# count_class 5
# labels 250
# 90
# dataset 250
# count_class 5
# labels 250
# 91
# dataset 250
# count_class 5
# labels 250
# 92
# dataset 250
# count_class 5
# labels 250
# 93
# dataset 250
# count_class 5
# labels 250
# 94
# dataset 250
# count_class 5
# labels 250
# 95
# dataset 250
# count_class 5
# labels 250
# 96
# dataset 250
# count_class 5
# labels 250
# 97
# dataset 250
# count_class 5
# labels 250
# 98
# dataset 250
# count_class 5
# labels 250
# 99
# dataset 250
# count_class 5
# labels 250
# 100
# dataset 250
# count_class 5
# labels 250
# 101
# dataset 250
# count_class 5
# labels 250
# 102
# dataset 250
# count_class 5
# labels 250
# 103
# dataset 250
# count_class 5
# labels 250
# 104
# dataset 250
# count_class 5
# labels 250
# 105
# dataset 250
# count_class 5
# labels 250
# 106
# dataset 250
# count_class 5
# labels 250
# 107
# dataset 250
# count_class 5
# labels 250
# 108
# dataset 250
# count_class 5
# labels 250
# 109
# dataset 250
# count_class 5
# labels 250
# 110
# dataset 250
# count_class 5
# labels 250
# 111
# dataset 250
# count_class 5
# labels 250
# 112
# dataset 250
# count_class 5
# labels 250
# 113
# dataset 250
# count_class 5
# labels 250
# 114
# dataset 250
# count_class 5
# labels 250
# 115
# dataset 250
# count_class 5
# labels 250
# 116
# dataset 250
# count_class 5
# labels 250
# 117
# dataset 250
# count_class 5
# labels 250
# 118
# dataset 250
# count_class 5
# labels 250
# 119
# dataset 250
# count_class 5
# labels 250
# 120
# dataset 250
# count_class 5
# labels 250
# 121
# dataset 250
# count_class 5
# labels 250
# 122
# dataset 250
# count_class 5
# labels 250
# 123
# dataset 250
# count_class 5
# labels 250
# 124
# dataset 250
# count_class 5
# labels 250
# 125
# dataset 250
# count_class 5
# labels 250
# 126
# dataset 250
# count_class 5
# labels 250
# 127
# dataset 250
# count_class 5
# labels 250
# 128
# dataset 250
# count_class 5
# labels 250
# 129
# dataset 250
# count_class 5
# labels 250
# 130
# dataset 250
# count_class 5
# labels 250
# 131
# dataset 250
# count_class 5
# labels 250
# 132
# dataset 250
# count_class 5
# labels 250
# 133
# dataset 250
# count_class 5
# labels 250
# 134
# dataset 250
# count_class 5
# labels 250
# 135
# dataset 250
# count_class 5
# labels 250
# 136
# dataset 250
# count_class 5
# labels 250
# 137
# dataset 250
# count_class 5
# labels 250
# 138
# dataset 250
# count_class 5
# labels 250
# 139
# dataset 250
# count_class 5
# labels 250
# 140
# dataset 250
# count_class 5
# labels 250
# 141
# dataset 250
# count_class 5
# labels 250
# 142
# dataset 250
# count_class 5
# labels 250
# 143
# dataset 250
# count_class 5
# labels 250
# 144
# dataset 250
# count_class 5
# labels 250
# 145
# dataset 250
# count_class 5
# labels 250
# 146
# dataset 250
# count_class 5
# labels 250
# 147
# dataset 250
# count_class 5
# labels 250
# 148
# dataset 250
# count_class 5
# labels 250
# 149
# dataset 250
# count_class 5
# labels 250
# 150
# dataset 250
# count_class 5
# labels 250
# 151
# dataset 250
# count_class 5
# labels 250
# 152
# dataset 250
# count_class 5
# labels 250
# 153
# dataset 250
# count_class 5
# labels 250
# 154
# dataset 250
# count_class 5
# labels 250
# 155
# dataset 250
# count_class 5
# labels 250
# 156
# dataset 250
# count_class 5
# labels 250
# 157
# dataset 250
# count_class 5
# labels 250
# 158
# dataset 250
# count_class 5
# labels 250
# 159
# dataset 250
# count_class 5
# labels 250
# 160
# dataset 250
# count_class 5
# labels 250
# 161
# dataset 250
# count_class 5
# labels 250
# 162
# dataset 250
# count_class 5
# labels 250
# 163
# dataset 250
# count_class 5
# labels 250
# 164
# dataset 250
# count_class 5
# labels 250
# 165
# dataset 250
# count_class 5
# labels 250
# 166
# dataset 250
# count_class 5
# labels 250
# 167
# dataset 250
# count_class 5
# labels 250
# 168
# dataset 250
# count_class 5
# labels 250
# 169
# dataset 250
# count_class 5
# labels 250
# 170
# dataset 250
# count_class 5
# labels 250
# 171
# dataset 250
# count_class 5
# labels 250
# 172
# dataset 250
# count_class 5
# labels 250
# 173
# dataset 250
# count_class 5
# labels 250
# 174
# dataset 250
# count_class 5
# labels 250
# 175
# dataset 250
# count_class 5
# labels 250
# 176
# dataset 250
# count_class 5
# labels 250
# 177
# dataset 250
# count_class 5
# labels 250
# 178
# dataset 250
# count_class 5
# labels 250
# 179
# dataset 250
# count_class 5
# labels 250
# 180
# dataset 250
# count_class 5
# labels 250
# 181
# dataset 250
# count_class 5
# labels 250
# 182
# dataset 250
# count_class 5
# labels 250
# 183
# dataset 250
# count_class 5
# labels 250
# 184
# dataset 250
# count_class 5
# labels 250
# 185
# dataset 250
# count_class 5
# labels 250
# 186
# dataset 250
# count_class 5
# labels 250
# 187
# dataset 250
# count_class 5
# labels 250
# 188
# dataset 250
# count_class 5
# labels 250
# 189
# dataset 250
# count_class 5
# labels 250
# 190
# dataset 250
# count_class 5
# labels 250
# 191
# dataset 250
# count_class 5
# labels 250
# 192
# dataset 250
# count_class 5
# labels 250
# 193
# dataset 250
# count_class 5
# labels 250
# 194
# dataset 250
# count_class 5
# labels 250
# 195
# dataset 250
# count_class 5
# labels 250
# 196
# dataset 250
# count_class 5
# labels 250
# 197
# dataset 250
# count_class 5
# labels 250
# 198
# dataset 250
# count_class 5
# labels 250
# 199
# dataset 250
# count_class 5
# labels 250
# 200
# dataset 250
# count_class 5
# labels 250
# 201
# dataset 250
# count_class 5
# labels 250
# 202
# dataset 250
# count_class 5
# labels 250
# 203
# dataset 250
# count_class 5
# labels 250
# 204
# dataset 250
# count_class 5
# labels 250
# 205
# dataset 250
# count_class 5
# labels 250
# 206
# dataset 250
# count_class 5
# labels 250
# 207
# dataset 250
# count_class 5
# labels 250
# 208
# dataset 250
# count_class 5
# labels 250
# 209
# dataset 250
# count_class 5
# labels 250
# 210
# dataset 250
# count_class 5
# labels 250
# 211
# dataset 250
# count_class 5
# labels 250
# 212
# dataset 250
# count_class 5
# labels 250
# 213
# dataset 250
# count_class 5
# labels 250
# 214
# dataset 250
# count_class 5
# labels 250
# 215
# dataset 250
# count_class 5
# labels 250
# 216
# dataset 250
# count_class 5
# labels 250
# 217
# dataset 250
# count_class 5
# labels 250
# 218
# dataset 250
# count_class 5
# labels 250
# 219
# dataset 250
# count_class 5
# labels 250
# 220
# dataset 250
# count_class 5
# labels 250
# 221
# dataset 250
# count_class 5
# labels 250
# 222
# dataset 250
# count_class 5
# labels 250
# 223
# dataset 250
# count_class 5
# labels 250
# 224
# dataset 250
# count_class 5
# labels 250
# 225
# dataset 250
# count_class 5
# labels 250
# 226
# dataset 250
# count_class 5
# labels 250
# 227
# dataset 250
# count_class 5
# labels 250
# 228
# dataset 250
# count_class 5
# labels 250
# 229
# dataset 250
# count_class 5
# labels 250
# 230
# dataset 250
# count_class 5
# labels 250
# 231
# dataset 250
# count_class 5
# labels 250
# 232
# dataset 250
# count_class 5
# labels 250
# 233
# dataset 250
# count_class 5
# labels 250
# 234
# dataset 250
# count_class 5
# labels 250
# 235
# dataset 250
# count_class 5
# labels 250
# 236
# dataset 250
# count_class 5
# labels 250
# 237
# dataset 250
# count_class 5
# labels 250
# 238
# dataset 250
# count_class 5
# labels 250
# 239
# dataset 250
# count_class 5
# labels 250
# 240
# dataset 250
# count_class 5
# labels 250
# 241
# dataset 250
# count_class 5
# labels 250
# 242
# dataset 250
# count_class 5
# labels 250
# 243
# dataset 250
# count_class 5
# labels 250
# 244
# dataset 250
# count_class 5
# labels 250
# 245
# dataset 250
# count_class 5
# labels 250
# 246
# dataset 250
# count_class 5
# labels 250
# 247
# dataset 250
# count_class 5
# labels 250
# 248
# dataset 250
# count_class 5
# labels 250
# 249
# <img src="data:image/png;base64,..." width="431.0333333333333">

# %% [markdown]
# ## Results and Analyse

# %%
from sklearn.metrics import confusion_matrix
import itertools
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    labels_names = ["Woman", "Man"]
    tick_marks = np.arange(len(labels_names))
    plt.xticks(tick_marks, labels_names, rotation=45)
    plt.yticks(tick_marks, labels_names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        pl.text(j, i, format(cm[i, j]),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
plot_confusion_matrix(conf_mat)

# %%
precision = (conf_mat[0][0]/(conf_mat[0][0] + conf_mat[1][0]) + conf_mat[1][1]/(conf_mat[1][1] + conf_mat[0][1]))/2
print("Precision: ", precision)
recall = (conf_mat[0][0]/(conf_mat[0][0] + conf_mat[0][1]) + conf_mat[1][1]/(conf_mat[1][1] + conf_mat[1][0]))/2
print("Recall: ", recall)
f1score = 2*(precision*recall)/(precision+recall)
print("F1-Score: ", f1score)
